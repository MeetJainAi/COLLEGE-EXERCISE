# %% [markdown]
# ## Coding Exercise 6
# ### MEET SHAH : C0854887

# %% [markdown]
# ![6.1.png](attachment:6.1.png)

# %%
##5.1 and 5.2
avenger = 'Iron man'
print("Is avenger == 'Iron man'? I predicted True")
print("avenger == 'Iron man'")

print("Is avenger == 'hulk'? I predicted False")
print("avenger == 'hulk'")

avenger1 = avenger.lower()
print("Is avenger1 == avenger ? I predicted Fasle")
print("avenger1 == avenger")


print("Is avenger1 != avenger ? I predicted True")
print("avenger1 != avenger")

movie = 'Avengers'
    
print("Is movie == 'Avengers'? I predicted True")
print("movie == 'Avengers'")

print("Is movie == 'hulk'? I predicted False")
print("movie == 'hulk'")

print("Is movie != 'Avengers'? I predicted True")
print("movie != 'Avengers'")

print("Is movie != 'hulk'? I predicted False")
print("movie != 'hulk'")

age = 20
age1=28
print("Is age>=20 ? I predicted True")
print("age>=20")

print("Is age>20 ? I predicted False")
print("age>20")

print("Is age<=20 ? I predicted True")
print("age<=20")

print("Is age<20 ? I predicted False")
print("age<20")

print("Is age>=20 and age1<=25 ? I predicted True")
print("age>=20 and age1<=25")

print("Is age>20 and age1<25 ? I predicted False")
print("age>20 and age1<25")

print("Is age>=20 or age1<=25 ? I predicted True")
print("age>=20 or age1<=25")

print("Is age>20 or age1<25 ? I predicted False")
print("age>20 or age1<25")

animals=['Lion','Tiger','Fox']
print("Is Lion in animals ? I predicted True")
print("'Lion' in animals")

print("Is Sheep in animals ? I predicted False")
print("'Sheep' in animals")

print("Is Lion not in animals ? I predicted False")
print("'Lion' not in animals")

print("Is Sheep not in animals ? I predicted True")
print("'Sheep' not in animals")
# Out:
# Is avenger == 'Iron man'? I predicted True
# avenger == 'Iron man'
# Is avenger == 'hulk'? I predicted False
# avenger == 'hulk'
# Is avenger1 == avenger ? I predicted Fasle
# avenger1 == avenger
# Is avenger1 != avenger ? I predicted True
# avenger1 != avenger
# Is movie == 'Avengers'? I predicted True
# movie == 'Avengers'
# Is movie == 'hulk'? I predicted False
# movie == 'hulk'
# Is movie != 'Avengers'? I predicted True
# movie != 'Avengers'
# Is movie != 'hulk'? I predicted False
# movie != 'hulk'
# Is age>=20 ? I predicted True
# age>=20
# Is age>20 ? I predicted False
# age>20
# Is age<=20 ? I predicted True
# age<=20
# Is age<20 ? I predicted False
# age<20
# Is age>=20 and age1<=25 ? I predicted True
# age>=20 and age1<=25
# Is age>20 and age1<25 ? I predicted False
# age>20 and age1<25
# Is age>=20 or age1<=25 ? I predicted True
# age>=20 or age1<=25
# Is age>20 or age1<25 ? I predicted False
# age>20 or age1<25
# Is Lion in animals ? I predicted True
# 'Lion' in animals
# ...

# %% [markdown]
# ![6.2.png](attachment:6.2.png)

# %%
##5.3
alien_colour = input("Enter Green,Yellow or Red??")
alien_colour=alien_colour.lower()
if alien_colour == 'green':
    print('You have just earned 5 points')
else:
    pass
# Out:
# Enter Green,Yellow or Red??green
# You have just earned 5 points

# %%
##5.4
alien_colour = input("Enter Green,Yellow or Red??")
alien_colour=alien_colour.lower()
if alien_colour == 'green':
    print('You have just earned 5 points')
else:
    print('You have just earned 10 points')
# Out:
# Enter Green,Yellow or Red??RED
# You have just earned 10 points

# %% [markdown]
# ![6.3.png](attachment:6.3.png)

# %%
##5.5
alien_colour = input("Enter Green,Yellow or Red??")
alien_colour=alien_colour.lower()
if alien_colour == 'green':
    print('You have just earned 5 points')
elif alien_colour=='yellow':
    print('You have just earned 10 points')
else:
    print('You have just earned 15 points')
# Out:
# Enter Green,Yellow or Red??YELLOW
# You have just earned 10 points

# %%
##5.6
age=int(input('Enter Your Age:'))
if age<2:
    print('Person is Baby')
elif age>=2 and age<4:
    print('Person is Toddler')
elif age>=4 and age <13:
    print('Person is Kid')
elif age>=13 and age<20:
    print('Person is Teenager')
elif age>=20 and age <65:
    print('Person is Adult')
elif age>=65:
    print('Person is Elder')
else:
    print('You have type something wrong')
# Out:
# Enter Your Age:22
# Person is Adult

# %%
##5.7
Favourite_fruits=['Grapes' , 'Apple' , 'WaterMelon']
if 'Banana' in Favourite_fruits:
    print('You really like Bananas')
if 'Grapes' in Favourite_fruits:
    print('You really like Grapes')
if 'Apple' in Favourite_fruits:
    print('You really like Apple')
if 'Cherry' in Favourite_fruits:
    print('You really like Cherry')
if 'WaterMelon' in Favourite_fruits:
    print('You really like WaterMelon')
# Out:
# You really like Grapes
# You really like Apple
# You really like WaterMelon

# %% [markdown]
# ![6.4.png](attachment:6.4.png)

# %%
##5.8
usernames=['Admin','Meet','Chirag','Kamini','Shiddharth']
for i in usernames:
    if i == 'Admin':
        print(f'Hello {i},Would you like to see Report')
    else:
        print(f'Hello {i}, Thank you for logging in Again!')
# Out:
# Hello Admin,Would you like to see Report
# Hello Meet, Thank you for logging in Again!
# Hello Chirag, Thank you for logging in Again!
# Hello Kamini, Thank you for logging in Again!
# Hello Shiddharth, Thank you for logging in Again!

# %%
##5.9
usernames=[]

if len(usernames)==0:
    print("We need to find some users!!")
# Out:
# We need to find some users!!

# %%
##5.10
current_users=['Meet','Chirag','Kamini','Shiddharth','Tony']

new_users=['Meet','Tony','Stark','Steve','Rogers']
for i in new_users:
    if i in current_users or i.upper() in current_users:
        print(f"{i} Please enter another username")
    else:
        print(f'{i} username is available')
# Out:
# Meet Please enter another username
# Tony Please enter another username
# Stark username is available
# Steve username is available
# Rogers username is available

# %%
##5.11
ordinal =[]
for i in range(1,11):
    if i == 1:
        ordinal.append(f"{i}st")
    elif i == 2:
         ordinal.append(f"{i}nd")
    elif i == 3:
         ordinal.append(f"{i}rd")
    else:
         ordinal.append(f"{i}th")
print(ordinal)
# Out:
# ['1st', '2nd', '3rd', '4th', '5th', '6th', '7th', '8th', '9th', '10th']
