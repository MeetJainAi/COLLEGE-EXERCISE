# %% [markdown]
# ## Coding Practice 3 For AML

# %% [markdown]
# ![2.1.png](attachment:2.1.png)

# %% [markdown]
# ## Solution

# %%
#2.1
my_name = "Meet Shah"
print(my_name)
# Out:
# Meet Shah

# %%
#2.2
my_name = "Meet Shah"
print(my_name)
my_name = "Tony Stark"
print(my_name)
# Out:
# Meet Shah
# Tony Stark

# %% [markdown]
# ![2.2.png](attachment:2.2.png)

# %%
##2.3
name=input("Enter your name...")
print(f"Hello {name} , Would you want to make money?" )
# Out:
# Enter your name...MEET SHAH
# Hello MEET SHAH , Would you want to make money?

# %%
##2.4
name = 'Iron Man'
print(f"Name in LowerCase:{name.lower()}")
print(f"Name in UpperCase:{name.upper()}")
print(f"Name in TiteCase:{name.title()}")
# Out:
# Name in LowerCase:iron man
# Name in UpperCase:IRON MAN
# Name in TiteCase:Iron Man

# %%
##2.5
print(f"Bobby Unser once said ,\"Success is where preparation and opportunity meet.\" ")
# Out:
# Bobby Unser once said ,"Success is where preparation and opportunity meet."

# %%
##2.6
quote = "Success is where preparation and opportunity meet."
author = "Bobby Unser"
print(f"{author} once said ,\"{quote}\" ")
# Out:
# Bobby Unser once said ,"Success is where preparation and opportunity meet."

# %%
##2.7
stripping = "        Tony Stark    Meet Shah       "
print(f"lstrip : {stripping.lstrip()}")
print(f"rstrip : {stripping.rstrip()}")
print(f"strip : {stripping.strip()}")
# Out:
# lstrip : Tony Stark    Meet Shah
# rstrip :         Tony Stark    Meet Shah
# strip : Tony Stark    Meet Shah

# %% [markdown]
# ![2.3.png](attachment:2.3.png)

# %%
##2.8
print(5+3)
print(12-4)
print(2*4)
print(16/2)
# Out:
# 8
# 8
# 8
# 8.0

# %%
Fav_number = 7
print(f"Your Favourite number is {Fav_number}")
# Out:
# Your Favourite number is 7
